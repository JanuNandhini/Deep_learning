# %% [markdown]
# VISUALIZATION OF THE ACTIVATION FUNCTIONS

# %%
print("24BAD041,Janu Nandhini E")
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 24BAD041,Janu Nandhini E

# %%
x=np.linspace(-10,10,400)
sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

# %%
plt.figure(figsize=(6, 4))
plt.plot(x,sigmoid)
plt.title("Sigmoid Activation function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(x,tanh)
plt.title("Tanh Activation function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(x,relu)
plt.title("ReLU Activation function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %% [markdown]
# PERFORMANCE COMPARISON OF ACTIVATION FUNCTIONS

# %%
print("24BAD041,JANU NANDHINI E")
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 24BAD041,JANU NANDHINI E

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train=x_train/255.0
x_test=x_test/255.0

# %%
def create_model(activation):
  model=tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(28,28)),
      tf.keras.layers.Dense(128,activation=activation),
      tf.keras.layers.Dense(64,activation=activation),
      tf.keras.layers.Dense(32,activation=activation),
      tf.keras.layers.Dense(10,activation='softmax')
  ])
  model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
  return model

# %%
activations = ['sigmoid', 'tanh', 'relu']

results = {}
histories = {}
for activation in activations:

    print("\nTraining with", activation)

    model = create_model(activation)
    history = model.fit(
        x_train,
        y_train,
        epochs=10,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )

    results[activation] = model.evaluate(
        x_test,
        y_test,
        verbose=0
    )
    histories[activation] = history
# Out:
# Training with sigmoid
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8275 - loss: 0.7181 - val_accuracy: 0.9308 - val_loss: 0.2591
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9414 - loss: 0.2103 - val_accuracy: 0.9530 - val_loss: 0.1641
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9595 - loss: 0.1424 - val_accuracy: 0.9613 - val_loss: 0.1382
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9702 - loss: 0.1061 - val_accuracy: 0.9652 - val_loss: 0.1225
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9764 - loss: 0.0826 - val_accuracy: 0.9667 - val_loss: 0.1150
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9822 - loss: 0.0648 - val_accuracy: 0.9689 - val_loss: 0.1073
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9854 - loss: 0.0524 - val_accuracy: 0.9711 - val_loss: 0.1035
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9885 - loss: 0.0428 - val_accuracy: 0.9718 - val_loss: 0.1018
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9902 - loss: 0.0350 - val_accuracy: 0.9732 - val_loss: 0.0958
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9927 - loss: 0.0266 - val_accuracy: 0.9689 - val_loss: 0.1115
#
# Training with tanh
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9150 - loss: 0.3015 - val_accuracy: 0.9501 - val_loss: 0.1681
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9596 - loss: 0.1331 - val_accuracy: 0.9678 - val_loss: 0.1126
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9722 - loss: 0.0922 - val_accuracy: 0.9643 - val_loss: 0.1107
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9784 - loss: 0.0692 - val_accuracy: 0.9676 - val_loss: 0.1068
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9831 - loss: 0.0540 - val_accuracy: 0.9698 - val_loss: 0.1083
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9862 - loss: 0.0439 - val_accuracy: 0.9691 - val_loss: 0.1124
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9887 - loss: 0.0355 - val_accuracy: 0.9714 - val_loss: 0.1037
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9905 - loss: 0.0298 - val_accuracy: 0.9693 - val_loss: 0.1137
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9926 - loss: 0.0241 - val_accuracy: 0.9746 - val_loss: 0.1021
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9934 - loss: 0.0215 - val_accuracy: 0.9714 - val_loss: 0.1153
#
# Training with relu
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9159 - loss: 0.2834 - val_accuracy: 0.9569 - val_loss: 0.1438
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9638 - loss: 0.1187 - val_accuracy: 0.9639 - val_loss: 0.1192
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9750 - loss: 0.0841 - val_accuracy: 0.9733 - val_loss: 0.0893
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9799 - loss: 0.0636 - val_accuracy: 0.9727 - val_loss: 0.0947
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9833 - loss: 0.0510 - val_accuracy: 0.9698 - val_loss: 0.1042
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9866 - loss: 0.0416 - val_accuracy: 0.9721 - val_loss: 0.1043
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9886 - loss: 0.0366 - val_accuracy: 0.9733 - val_loss: 0.0989
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9910 - loss: 0.0269 - val_accuracy: 0.9730 - val_loss: 0.1096
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9906 - loss: 0.0277 - val_accuracy: 0.9722 - val_loss: 0.1102
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9930 - loss: 0.0219 - val_accuracy: 0.9758 - val_loss: 0.1105

# %%
print("\nFINAL RESULTS")

for activation in activations:

    loss, accuracy = results[activation]

    history = histories[activation]

    print("\nActivation:", activation)
    print("Training Accuracy:",
          history.history['accuracy'][-1])
    print("Validation Accuracy:",
          history.history['val_accuracy'][-1])

    print("Training Loss:",
          history.history['loss'][-1])

    print("Validation Loss:",
          history.history['val_loss'][-1])
# Out:
# FINAL RESULTS
#
# Activation: sigmoid
# Training Accuracy: 0.9927499890327454
# Validation Accuracy: 0.968916654586792
# Training Loss: 0.026614531874656677
# Validation Loss: 0.11152826249599457
#
# Activation: tanh
# Training Accuracy: 0.9933541417121887
# Validation Accuracy: 0.9714166522026062
# Training Loss: 0.021517960354685783
# Validation Loss: 0.11529222875833511
#
# Activation: relu
# Training Accuracy: 0.9929791688919067
# Validation Accuracy: 0.9757500290870667
# Training Loss: 0.0218749288469553
# Validation Loss: 0.11045584082603455

# %%
plt.figure(figsize=(8, 5))

for activation in activations:
    plt.plot(
        histories[activation].history['val_accuracy'],
        label=activation
    )

plt.title("Validation Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(8, 5))

for activation in activations:
    plt.plot(
        histories[activation].history['val_loss'],
        label=activation
    )

plt.title("Validation Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# COMPARISON OF THE OPTIMIZATION ALGORITHMS

# %%
print("24BAD041,Janu Nandhini E")
import tensorflow as tf
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# 24BAD041,Janu Nandhini E

# %%
def create_model(optimizer):

    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),

        tf.keras.layers.Dense(128, activation='relu'),

        tf.keras.layers.Dense(64, activation='relu'),

        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
optimizers = {
    "SGD": tf.keras.optimizers.SGD(learning_rate=0.01),

    "Momentum": tf.keras.optimizers.SGD(
        learning_rate=0.01,
        momentum=0.9
    ),

    "RMSprop": tf.keras.optimizers.RMSprop(
        learning_rate=0.001
    ),

    "Adam": tf.keras.optimizers.Adam(
        learning_rate=0.001
    )
}


histories = {}
results = {}

# %%
for name, optimizer in optimizers.items():

    print("\n==============================")
    print("Training with:", name)
    print("==============================")

    model = create_model(optimizer)

    history = model.fit(
        x_train,
        y_train,
        epochs=10,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9885 - loss: 0.0386 - val_accuracy: 0.9694 - val_loss: 0.1421
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9902 - loss: 0.0321 - val_accuracy: 0.9697 - val_loss: 0.1363
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9914 - loss: 0.0281 - val_accuracy: 0.9730 - val_loss: 0.1155
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9930 - loss: 0.0229 - val_accuracy: 0.9759 - val_loss: 0.1279
#
# ==============================
# Training with: Adam
# ==============================
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9205 - loss: 0.2691 - val_accuracy: 0.9550 - val_loss: 0.1469
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9662 - loss: 0.1119 - val_accuracy: 0.9690 - val_loss: 0.1057
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9764 - loss: 0.0761 - val_accuracy: 0.9663 - val_loss: 0.1127
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9809 - loss: 0.0588 - val_accuracy: 0.9714 - val_loss: 0.0975
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9862 - loss: 0.0433 - val_accuracy: 0.9690 - val_loss: 0.1151
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9888 - loss: 0.0346 - val_accuracy: 0.9748 - val_loss: 0.1019
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9900 - loss: 0.0300 - val_accuracy: 0.9729 - val_loss: 0.1049
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9915 - loss: 0.0261 - val_accuracy: 0.9737 - val_loss: 0.1109
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9930 - loss: 0.0209 - val_accuracy: 0.9743 - val_loss: 0.1105
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9938 - loss: 0.0180 - val_accuracy: 0.9747 - val_loss: 0.1132

# %%
print("\n\nFINAL RESULTS")
print("=" * 70)

for name, result in results.items():

    print("\nOptimizer:", name)
    print("Training Accuracy:",
          round(result["Training Accuracy"], 4))

    print("Validation Accuracy:",
          round(result["Validation Accuracy"], 4))

    print("Training Loss:",
          round(result["Training Loss"], 4))

    print("Validation Loss:",
          round(result["Validation Loss"], 4))
# Out:
# FINAL RESULTS
# ======================================================================
#
# Optimizer: SGD
# Training Accuracy: 0.9629
# Validation Accuracy: 0.9611
# Training Loss: 0.1303
# Validation Loss: 0.1381
#
# Optimizer: Momentum
# Training Accuracy: 0.9949
# Validation Accuracy: 0.9767
# Training Loss: 0.0175
# Validation Loss: 0.0939
#
# Optimizer: RMSprop
# Training Accuracy: 0.993
# Validation Accuracy: 0.9759
# Training Loss: 0.0229
# Validation Loss: 0.1279
#
# Optimizer: Adam
# Training Accuracy: 0.9938
# Validation Accuracy: 0.9747
# Training Loss: 0.018
# Validation Loss: 0.1132

# %%
plt.figure(figsize=(9, 5))

for name in histories:

    plt.plot(
        histories[name].history['loss'],
        label=name
    )

plt.title("Training Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(9, 5))

for name in histories:

    plt.plot(
        histories[name].history['val_loss'],
        label=name
    )

plt.title("Validation Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(9, 5))

for name in histories:

    plt.plot(
        histories[name].history['accuracy'],
        label=name
    )

plt.title("Training Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(9, 5))

for name in histories:

    plt.plot(
        histories[name].history['val_accuracy'],
        label=name
    )

plt.title("Validation Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid()
plt.show()
